# %% [markdown]
# # Introduction to Matplotlib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.style.available
plt.style.use('seaborn-darkgrid')

# %%
plt.plot();

# %%
x = [1,2,3,4]
y = [10,8,6,9]
plt.plot(x,y, color='red'); # put; to remove <matplotlib.lines.Line2D at 0x18fa110a460>

# %% [markdown]
# ### Pyplot API or Oject-Oriented API
# * Pyplot API - Quickly
# * OO API - Advanced

# %%
x = np.linspace(0,10,1000)
plt.plot(x, np.sin(x), color='blue', linestyle='dashed', label='sin(x)');
plt.plot(x, np.cos(x), color='red', label='cos(x)')

plt.xlabel('X Variable')
plt.ylabel('Sin of X')

# plt.xlim([0,4])
# plt.ylim([-0.6, 0.6])

plt.legend()
plt.title('Sin(x) and Cos(x)')

# plt.axis([0,4,-0.7,0.6])
plt.axis("tight")
plt.axis('equal')

plt.show()

# %% [markdown]
# ### Object-Oriented API

# %%
# Step 1: Prepare data
x = [1,2,3,4]
y = [11,22,33,44]

# Step 2: Setup plot
fig, ax = plt.subplots(figsize=(5,5)) # Figure size = Width and Height of the plot

# Step 3: Plot the data
ax.plot(x,y);

ax.set(title = 'Simple Plot',
      xlabel = 'x-axis',
      ylabel = 'y-label');

# %% [markdown]
# ### 2. Most common types of Matplotlib plots
# * line
# * scatter
# * bar
# * hist
# * subplots()

# %% [markdown]
# ### Line chart

# %%
# Create an array
x = np.linspace(0,10,100)
x[:5]
# Out:
# array([0.       , 0.1010101, 0.2020202, 0.3030303, 0.4040404])

# %%
# OO API plot a line chart
fig, ax = plt.subplots()
ax.plot(x, x**3);

# %% [markdown]
# ### Scatter

# %%
# Pyplot API
plt.scatter(x,np.exp(x)) # y = e^(x)

# %%
# OO API

# Prepare new data
rng = np.random.RandomState(0)

x = rng.randn(100)
y = rng.randn(100)

# Size
sizes = 1000*rng.rand(100) 

# Color
colors = rng.rand(100)

fig, ax = plt.subplots()

img1 = ax.scatter(x,y,s=sizes, c=colors, cmap='viridis', alpha=0.3);

fig.colorbar(img1)

# %% [markdown]
# ### Bar chart
# * Vertical
# * Horizontal

# %%
# Prepare data from a Python dictionary
soft_drink_prices = {'Coke': 10,
                    'Pepsi': 12,
                    'Sprite': 8}
fig, ax = plt.subplots()
ax.bar(soft_drink_prices.keys(), soft_drink_prices.values())
ax.set(title='Bach Hoa Xanh soft drinkt prices',
      ylabel = 'Price ($)')
# Out:
# [Text(0.5, 1.0, 'Bach Hoa Xanh soft drinkt prices'), Text(0, 0.5, 'Price ($)')]

# %%
fig, ax = plt.subplots()
ax.barh(list(soft_drink_prices.keys()), list(soft_drink_prices.values()));

# %% [markdown]
# ### 4. Histogram

# %%
# Prepare data
np.random.seed(42)
student_heights = np.random.normal(170, 10, 250)
student_heights[:10]
# Out:
# array([174.96714153, 168.61735699, 176.47688538, 185.23029856,
#        167.65846625, 167.65863043, 185.79212816, 177.67434729,
#        165.30525614, 175.42560044])

# %%
# pyplot API
plt.hist(student_heights, bins=10);

# %% [markdown]
# ### Subplots
# * Multi plots on 1 figure

# %%
# Option 1: 
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2,
                      ncols=2,
                      figsize=(10,5));

# Plot data to each axis
ax1.plot(x, x/2)

ax2.scatter(np.random.random(10), np.random.random(10))

ax3.barh(list(soft_drink_prices.keys()), list(soft_drink_prices.values()));

ax4.hist(student_heights, bins=10);

# %%
# Options 2:
fig, ax = plt.subplots(nrows = 2,
                      ncols = 2,
                      figsize = (10, 5))
# Plot data to each axis
ax[0,0].plot(x, x/2)

ax[0,1].scatter(np.random.random(10), np.random.random(10))

ax[1,0].barh(list(soft_drink_prices.keys()), list(soft_drink_prices.values()));

ax[1,1].hist(student_heights, bins=10);

# %% [markdown]
# # Project: Data Visualization - California Cities

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
cities = pd.read_csv('./data/california_cities.csv')

# %%
cities.head()

cities['area_total_km2'].sort_values(ascending=False)
# Out:
# 239    1302.000
# 367     964.510
# 55      527.401
# 375     466.109
# 26      371.946
#          ...
# 163         NaN
# 237         NaN
# 370         NaN
# 393         NaN
# 443         NaN
# Name: area_total_km2, Length: 482, dtype: float64

# %%
# Extract latitude and longtitude
lat, lon = cities['latd'], cities['longd']
population, area = cities['population_total'], cities['area_total_km2']

# Plot using pyplot API
plt.style.use('seaborn')
plt.figure(figsize=(8,6))

plt.scatter(lon,lat, c=np.log10(population), cmap='viridis', s=area, linewidths=0, alpha=0.5);
plt.axis('equal')
plt.xlabel("Longtitude")
plt.ylabel('Latitude')
plt.title('California Cities Population and Area Distribution')
plt.colorbar(label='log$_{10}${population}');

plt.clim(3,7)

# Create the legend for cities size
area_range = [50, 100, 300, 500]
for area in area_range:
    plt.scatter([], [], s=area, c='k', alpha=0.4, label=str(area) + 'km$^2$')

plt.legend(labelspacing=1, title='Cities legend')

# %% [markdown]
# # The end
